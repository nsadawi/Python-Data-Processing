# %%
import pandas as pd

# %%
excel_file = pd.ExcelFile('/home/noureddin/Downloads/model.xls')

# %%
excel_file

# %%
excel_file.sheet_names[0]
# Out:
# 'model.xls'

# %%
df = excel_file.parse(excel_file.sheet_names[0])

# %%
df
# Out:
#                     CHOOSING THE RIGHT VALUATION MODEL  \
# NaN                                                NaN
# NaN  This program is designed to help in choosing t...
# NaN                             use for any occassion.
# NaN                                                NaN
# NaN                                Inputs to the model
# NaN                                  Level of Earnings
# NaN                       Are your earnings positive ?
# NaN                                                NaN
# NaN  If the earnings are positive and normal, pleas...
# NaN  What is the expected inflation rate in the eco...
# NaN  What is the expected real growth rate in the e...
# NaN                                                NaN
# NaN  What is the expected growth rate in earnings (...
# NaN  Does this firm have a significant and sustaina...
# NaN  Differential Advantages: High growth comes fro...
# NaN  possessed by the firm over its competitors. Th...
# ...
