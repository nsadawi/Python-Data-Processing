# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#enable IPython to display matplotlib graphs
# %matplotlib inline

# %%
raw_data = {
         "city": ["Tripoli", "Sydney", "Tripoli", "Rome", "Rome", "Tripoli","Rome", "Sydney", "Sydney"],
         "rank": ["1st", "2nd", "1st", "2nd", "1st", "2nd","1st", "2nd", "1st"], 
         "score1": [44, 48, 39, 41, 38, 44, 34, 54, 61],
         "score2": [67, 63, 55, 70, 64, 75, 45, 66, 72]
        }
        
df = pd.DataFrame(raw_data, 
                  index = pd.Index(['A','B','C','D','E','F','G','H','I'], name='letter'),
                  columns = pd.Index(['city', 'rank','score1','score2'],name='attributes'))

# %%
my_plot = df.plot(df['city'], kind='bar',legend=True)
my_plot.set_xlabel("City")
my_plot.set_ylabel("Score Value")

# %%
my_plot = df.plot(df['city'] ,figsize=(9, 7))
my_plot.set_xlabel("City")
my_plot.set_ylabel("Score Value")
my_plot.set_title('My stacked barplot')

# %%
df['score1']
# Out:
# letter
# A    44
# B    48
# C    39
# D    41
# E    38
# F    44
# G    34
# H    54
# I    61
# Name: score1, dtype: int64

# %%
hist_plot = df['score1'].hist(bins=9)
hist_plot.set_title('Score1 Histogram')
hist_plot.set_xlabel('Score Value')
hist_plot.set_ylabel('Frequency')

# %%
my_plot = df.plot(df['city'] ,figsize=(9, 7))
my_plot.set_xlabel("City")
my_plot.set_ylabel("Score Value")
